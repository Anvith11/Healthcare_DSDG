# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("NHE2024.csv", encoding='latin1', header=None)
df
# Out:
#                                                     0       1       2   \
# 0    NATIONAL HEALTH EXPENDITURES BY TYPE OF SERVIC...     NaN     NaN
# 1                        Expenditure Amount (Millions)    1960    1961
# 2                   Total National Health Expenditures  27,122  29,060
# 3                                        Out of pocket  12,778  13,193
# 4                                     Health Insurance   7,324   8,043
# ..                                                 ...     ...     ...
# 540                              State and Local Gov't      54      55
# 541  * Other Federal Programs include OEO, Federal ...     NaN     NaN
# 542  ** Other State and Local Programs include Stat...     NaN     NaN
# 543  NOTE: Numbers may not add to totals due to rou...     NaN     NaN
# 544  SOURCE:  Centers for Medicare & Medicaid Servi...     NaN     NaN
#
#          3       4       5       6       7       8       9   ...         56  \
# ...

# %%
years = df.iloc[1, 1:].tolist()
df.columns = ['Category'] + years
df = df.drop(index=[0, 1]).reset_index(drop=True)

# %%
df
# Out:
#                                               Category    1960    1961  \
# 0                   Total National Health Expenditures  27,122  29,060
# 1                                        Out of pocket  12,778  13,193
# 2                                     Health Insurance   7,324   8,043
# 3                             Private Health Insurance   5,639   6,275
# 4                                             Medicare    -       -
# ..                                                 ...     ...     ...
# 538                              State and Local Gov't      54      55
# 539  * Other Federal Programs include OEO, Federal ...     NaN     NaN
# 540  ** Other State and Local Programs include Stat...     NaN     NaN
# 541  NOTE: Numbers may not add to totals due to rou...     NaN     NaN
# 542  SOURCE:  Centers for Medicare & Medicaid Servi...     NaN     NaN
#
#        1962    1963    1964    1965    1966    1967    1968  ...       2015  \
# ...

# %% [markdown]
# **Transpose dataset**

# %%
df = df.set_index('Category').T.reset_index()
df = df.rename(columns={'index': 'Year'})

# %% [markdown]
# **rename rows into their years**

# %%
df
# Out:
# Category  Year Total National Health Expenditures      Out of pocket  \
# 0         1960                             27,122             12,778
# 1         1961                             29,060             13,193
# 2         1962                             31,765             14,085
# 3         1963                             34,558             15,171
# 4         1964                             38,245             16,669
# ..         ...                                ...                ...
# 60        2020                          4,204,311            412,276
# 61        2021                          4,376,932            457,160
# 62        2022                          4,586,625            491,924
# 63        2023                          4,925,324            525,424
# 64        2024                          5,278,588            556,554
#
# Category      Health Insurance           Private Health Insurance  \
# 0                        7,324                              5,639
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Total National Health Expenditures', '     Out of pocket',
#        '     Health Insurance', '          Private Health Insurance',
#        '          Medicare', '          Medicaid (Title XIX)',
#        '                          Federal  ',
#        '                          State and Local',
#        '          CHIP (Title XIX and Title XXI)',
#        ...
#        '         Federal Gov't', '         State and Local Gov't',
#        '     Equipment', '          Private ', '          Federal Gov't',
#        '          State and Local Gov't',
#        '* Other Federal Programs include OEO, Federal General and Medical, Federal General and Medical NEC, and High Risk Pools under ACA',
#        '** Other State and Local Programs include State and Local Subsidies and TDI',
# ...

# %% [markdown]
# **Total health expenditures seems like the target variable**

# %%
(df.isna().sum() / len(df)).sort_values(ascending=False) * 100
# Out:
# Category
# SOURCE:  Centers for Medicare & Medicaid Services, Office of the Actuary, National Health Statistics Group.    100.0
#          Other State and Local Programs**                                                                      100.0
#      Out of pocket                                                                                             100.0
#          Worksite Health Care                                                                                  100.0
#          Other Private Revenues                                                                                100.0
#                                                                                                                ...
#          Worksite Health Care                                                                                    0.0
#      Other Third Party Payers and Programs                                                                       0.0
# ...

# %%
df = df.iloc[:, :-4]

# %%
df
# Out:
# Category  Year Total National Health Expenditures      Out of pocket  \
# 0         1960                             27,122             12,778
# 1         1961                             29,060             13,193
# 2         1962                             31,765             14,085
# 3         1963                             34,558             15,171
# 4         1964                             38,245             16,669
# ..         ...                                ...                ...
# 60        2020                          4,204,311            412,276
# 61        2021                          4,376,932            457,160
# 62        2022                          4,586,625            491,924
# 63        2023                          4,925,324            525,424
# 64        2024                          5,278,588            556,554
#
# Category      Health Insurance           Private Health Insurance  \
# 0                        7,324                              5,639
# ...

# %%
df = df.iloc[6:]
df
# Out:
# Category  Year Total National Health Expenditures      Out of pocket  \
# 6         1966                             45,752             18,132
# 7         1967                             51,186             17,985
# 8         1968                             58,015             19,951
# 9         1969                             65,417             21,911
# 10        1970                             74,077             24,208
# 11        1971                             82,380             25,515
# 12        1972                             92,385             27,805
# 13        1973                            102,654             30,737
# 14        1974                            116,313             33,295
# 15        1975                            132,656             36,031
# 16        1976                            152,022             39,278
# 17        1977                            172,642             43,133
# 18        1978                            193,947             46,035
# ...

# %%
df = df.drop(df.columns[9:12], axis=1)
df
# Out:
# Category  Year Total National Health Expenditures      Out of pocket  \
# 6         1966                             45,752             18,132
# 7         1967                             51,186             17,985
# 8         1968                             58,015             19,951
# 9         1969                             65,417             21,911
# 10        1970                             74,077             24,208
# 11        1971                             82,380             25,515
# 12        1972                             92,385             27,805
# 13        1973                            102,654             30,737
# 14        1974                            116,313             33,295
# 15        1975                            132,656             36,031
# 16        1976                            152,022             39,278
# 17        1977                            172,642             43,133
# 18        1978                            193,947             46,035
# ...

# %%
df.columns.tolist()
# Out:
# ['Year',
#  'Total National Health Expenditures',
#  '     Out of pocket',
#  '     Health Insurance',
#  '          Private Health Insurance',
#  '          Medicare',
#  '          Medicaid (Title XIX)',
#  '         Department of Defense',
#  '         Department of Veterans Affairs',
#  '     Other Third Party Payers and Programs',
#  '         Worksite Health Care',
#  '         Other Private Revenues',
#  '         Indian Health Services ',
#  "         Workers' Compensation",
#  '         General Assistance',
#  '         Maternal/Child Health',
#  '         Vocational Rehabilitation',
#  '         Other Federal Programs*',
#  '         SAMHSA',
#  '         Other State and Local Programs**',
#  '         School Health',
#  '     Public Health Activity',
#  '     Investment',
#  '         Research',
#  '         Structures & Equipment',
#  'Total CMS Programs (Medicaid, CHIP and Medicare)',
#  'POPULATION',
#  'Health Consumption Expenditures',
#  '     Out of pocket',
# ...
