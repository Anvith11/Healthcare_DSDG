# %% [markdown]
# # Exploratory Data Analysis
# Team: Anvith Mulpuri, Ansh Pathapati, Sahana Subramanyam, Akhila Arhla, Raahim Jawad
#
# Dataset: https://apps.who.int/nha/database/Select/Indicators/en

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Data_Table 1.csv")
df
# Out:
# /var/folders/qq/qybk1kgs5xb3qkzmrn3x53qh0000gn/T/ipykernel_72126/3756995087.py:1: DtypeWarning: Columns (6,19,20,21,22,33,100,106,123,124,125,130,142,148,150,154,159,160,161,162,165,166,167,173,197,198,199,203,204,205,206,208,209,210,213,221,225,235,238,239,241,242,243,244,249,250,252,253,254,256,257,258,261,263,264,265,269,270,271,272,273,278,288,293,294,295,296,298,300,301,302,304,305,306,309,310,311,312,315,316,317,318,319,320,321,328,333,334,339,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,367,368,369,370,371,372,373,374,375,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,399,400,401,402,403,404,405,414,422,440,441,466,467,468,469,471,472,473,474,475,479,480,481,482,483,489,492,495,496,497,500,504,507,509,510,511,512,514,515,516,517,519,520,521,522,523,524,526,527,528,529,532,533,534,535,536,538,541,542,543,544,549,550,554,556,558,560,562,574,575,578,579,584,586,587,590,591,593,595,598,599,633,653,654,656,658,670,671,673,676,677,679,680,681,686,689,690,692,694,695,697,698,699,700,702,703,704,708,710,711,712,713,714,716,719,720,725,726,727,728,729,744,745,746,747,748,750,751,752,757,758,759,760,761,762,763,764,765,766,769,770,772,776,778,779,780,781,782,785,787,789,791,796,797,801,804,805,806,808,809,812,813,814,815,816,818,830,836,837,844,846,855,863,872,874,877,878,879,880,881,884,885,886,887,889,890,891,892,895,896,897,903,907,920,924,927,928,929,932,934,935,936,938,939,940,942,943,946,947,949,951,952,953,954,955,959,965,966,967,969,971,973,974,979,980,985,986,987,989,990,991,993,994,995,997,998,999) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Data_Table 1.csv")
#       location code region        income  year  che_gdp che_pc_usd  \
# 0      Algeria  DZA    AFR  Upper-middle  2000      3.2         62
# 1      Algeria  DZA    AFR  Upper-middle  2001      3.5         67
# 2      Algeria  DZA    AFR  Upper-middle  2002      3.4         67
# 3      Algeria  DZA    AFR  Upper-middle  2003      3.3         76
# 4      Algeria  DZA    AFR  Upper-middle  2004      3.3         93
# ...        ...  ...    ...           ...   ...      ...        ...
# 4607  Viet Nam  VNM    WPR  Lower-middle  2019      5.0        171
# 4608  Viet Nam  VNM    WPR  Lower-middle  2020      4.3        153
# 4609  Viet Nam  VNM    WPR  Lower-middle  2021      4.5        168
# 4610  Viet Nam  VNM    WPR  Lower-middle  2022      4.5        188
# 4611  Viet Nam  VNM    WPR  Lower-middle  2023      4.6        197
#
#               che        gghed         pvtd  ... hc51_ext_ncu_pc  \
# 0         143,870      103,534       40,261  ...             NaN
# 1         162,231      123,664       38,492  ...             NaN
# 2         168,702      126,997       41,630  ...             NaN
# 3         189,137      145,057       43,985  ...             NaN
# 4         217,929      155,500       62,327  ...             NaN
# ...           ...          ...          ...  ...             ...
# 4607  383,361,920  155,721,575  223,880,400  ...             NaN
# 4608  348,498,752  144,046,531  198,600,896  ...             NaN
# 4609  385,155,232  166,379,650  214,197,904  ...             NaN
# 4610  436,627,072  189,599,779  240,079,456  ...             NaN
# 4611  470,719,168  208,542,770  256,781,504  ...             NaN
#
#       hc511_ext_ncu_pc  hc512_ext_ncu_pc  hc513_ext_ncu_pc  hc52_ext_ncu_pc  \
# 0                  NaN               NaN               NaN              NaN
# 1                  NaN               NaN               NaN              NaN
# 2                  NaN               NaN               NaN              NaN
# 3                  NaN               NaN               NaN              NaN
# 4                  NaN               NaN               NaN              NaN
# ...                ...               ...               ...              ...
# 4607               NaN               NaN               NaN              NaN
# 4608               NaN               NaN               NaN              NaN
# 4609               NaN               NaN               NaN              NaN
# 4610               NaN               NaN               NaN              NaN
# 4611               NaN               NaN               NaN              NaN
#
#       hc5nec_ext_ncu_pc  hc6_ext_ncu_pc  hc61_ext_ncu_pc  hc62_ext_ncu_pc  \
# 0                   NaN             NaN              NaN              NaN
# 1                   NaN             NaN              NaN              NaN
# 2                   NaN             NaN              NaN              NaN
# 3                   NaN             NaN              NaN              NaN
# 4                   NaN             NaN              NaN              NaN
# ...                 ...             ...              ...              ...
# 4607                NaN             NaN              NaN              NaN
# 4608                NaN             NaN              NaN              NaN
# 4609                NaN             NaN              NaN              NaN
# 4610                NaN             NaN              NaN              NaN
# 4611                NaN             NaN              NaN              NaN
#
#      fp3214_ext_ncu_pc
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 4607               NaN
# 4608               NaN
# 4609               NaN
# 4610               NaN
# 4611               NaN
#
# [4612 rows x 1000 columns]

# %%
print("Number of rows:", len(df))
# Out:
# Number of rows: 4612

# %%
print("Number of columns:", len(df.columns))
# Out:
# Number of columns: 1000

# %%
print("Names of columns:" , df.columns)
# Out:
# Names of columns: Index(['location', 'code', 'region', 'income', 'year', 'che_gdp', 'che_pc_usd',
#        'che', 'gghed', 'pvtd',
#        ...
#        'hc51_ext_ncu_pc', 'hc511_ext_ncu_pc', 'hc512_ext_ncu_pc',
#        'hc513_ext_ncu_pc', 'hc52_ext_ncu_pc', 'hc5nec_ext_ncu_pc',
#        'hc6_ext_ncu_pc', 'hc61_ext_ncu_pc', 'hc62_ext_ncu_pc',
#        'fp3214_ext_ncu_pc'],
#       dtype='object', length=1000)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4612 entries, 0 to 4611
# Columns: 1000 entries, location to fp3214_ext_ncu_pc
# dtypes: float64(250), int64(2), object(748)
# memory usage: 35.2+ MB
